# %%
import pyodbc 
import csv
import urllib2

# %%
pyodbc.drivers()
# Out:
# ['ODBC Driver 17 for SQL Server']

# %%
# server = 'tcp:myserver.database.windows.net' 
server = 'localhost,1433' 
database = 'MyTestingDb' 
username = 'tester123'
password = 'testing123!' 

cnxn = pyodbc.connect('DRIVER={ODBC Driver 17 for SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password)

#     'DRIVER={ODBC Driver 17 for SQL Server};SERVER='+server+';DATABASE='+database+';UID='+username+';PWD='+ password
cursor = cnxn.cursor()

# %%
url = 'https://cache.getdata.io/n91330_38d976375c1afd21fc0675c1b4d70d1ceses/1620100334_all.csv'
response = urllib2.urlopen(url)
reader = csv.DictReader(response)

for line in reader:
    print line
    clean_price = line["price"];
    clean_price = clean_price.replace('$', '')
    if len(clean_price) == 0:
        clean_price = 0

    cursor.execute(
        "insert into Inventory(manufacturing_number, product_name, manufacturer_number, price) values (?, ?, ?, ?)", 
        line["manufacturing_number"], 
        line["product name"], 
        line["manufacturer number"], 
        float(clean_price)
    )
    cnxn.commit()
# Out:
# {'origin_pattern': 'https://www.staplesadvantage.com/sahome', 'manufacturing_number': '05319BK11045', 'origin_url': 'https://www.staplesadvantage.com/sahome', 'manufacturer number': '', 'pingedAt': '2021-05-04 03:52:14', 'product name': 'Access Denied', 'updatedAt': '2021-05-04 03:52:14', 'price': '', 'createdAt': '2021-05-04 03:52:14'}
# {'origin_pattern': 'https://www.staplesadvantage.com/sahome', 'manufacturing_number': '054901-CTN', 'origin_url': 'https://www.staplesadvantage.com/sahome', 'manufacturer number': 'DPS08511RCYCC', 'pingedAt': '2021-05-04 03:52:14', 'product name': 'Diversity Products Solutions by Staples Copy Paper, 8.5" x 11", 20 lbs., White, 500 Sheets/Ream, 10 Reams/Carton', 'updatedAt': '2021-05-04 03:52:14', 'price': '$70.29', 'createdAt': '2021-05-04 03:52:14'}
# ...
